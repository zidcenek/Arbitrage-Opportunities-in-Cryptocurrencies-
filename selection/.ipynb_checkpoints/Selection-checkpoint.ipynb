# %% [markdown]
# TODO:
# - všechny soubory
# - správně dělení/násobení
# - optimalizace
# - uložení do souborů (data jsou již ve správném json tvaru)

# %%
import pandas as pd
from os import listdir
from os.path import isfile, join

MYPATH = "./data/"


class Files_reader:
    def __init__(self):
        self.all_files = None
    
    
    def fetch_filenames(self):
        try:
            self.all_files = [f for f in listdir(MYPATH) if isfile(join(MYPATH, f))] 
        except e:
            print(e)

    
    def files_selection(self):
        try:
            date = self.all_files[0][-11::1]
        except: 
            return None
        match = []
        does_not_match = []
        for f in self.all_files:
            if f[-8::1] == date:
                match.append(f)
            else:
                does_not_match.append(f)
        self.all_files = does_not_match
        return match

    def files_combinations(files):
        passs
        
    
    def read_files(self):
        if self.all_files is None:
            self.fetch_filenames()
        selected = self.files_selection()
        if selected is None or self.all_files is None:
            return None
        dataframes = []
        for filename in selected:
            tmp = pd.read_csv(MYPATH + filename, sep=';', usecols=[0, 1, 2, 3], header=None, names=['id', 'demand', 'supply', 'timestamp'])
            dataframes.append(tmp)
        return dataframes

# %%
def split_string_to_array(field):
    field = field[0:-1]
    tmp = field.split("'")[1::2]
    return [float(i) for i in tmp]

# %%
class Currency_pair:
    def __init__(self, row):
        self._row = row
        self._trade_id = row["id"]
        self._supply = split_string_to_array(str(row['supply'].values))
        self._demand = split_string_to_array(str(row['demand'].values))
        self._timestamp = row["timestamp"]
        
    @property
    def trade_id(self):
        return self._trade_id
    
    @property
    def supply(self):
        return self._supply
    
    @property
    def demand(self):
        return self._demand
    
    @property
    def timestamp(self):
        return self._timestamp
    
    def printout(self):
        print(self.trade_id)
        print(self.supply)
        print(self.demand)
        print(self.timestamp)
        
    def to_json(self):
        return self._row.to_json()

# %%
import itertools

filenames = [
    "data/BNBBTC-2020-02-05",
    "data/BCHBNB-2020-02-05",
    "data/BCHBTC-2020-02-05"
]
filenames = [
    "BNBBTC-2020-02-05",
    "BCHBNB-2020-02-05",
    "BCHBTC-2020-02-05"
]

currencies = ["USDT", "BTC", "LTC", "ETH", "XRP", "BCH", "EOS", "BNB", "TRX", "XMR"]

def get_comb(files):
    '''Generator iterating over all possible combinations and yielding valid combinations'''
    all_combinations = itertools.combinations(currencies, 3)
    for comb in all_combinations:
        fit = [f for f in files if set(f).issubset(comb)]
        if len(fit) == 3:
            yield fit
    yield None

def filenames_combinations(files):
    date = files[0][-11::]
    for i in range(len(files)):
        f = files[i][0:-11:]
        if len(f) == 6:
            files[i] = (f[0:3], f[-3::])
        elif len(f) == 7:
            files[i] = (f[0:3], f[-4::])
            
    gen = get_comb(files)  # generator 
    comb = next(gen)
    while comb is not None:
        print(comb)
        ret = []
        for c in comb:
            ret.append(c[0] + c[1] + date)
        yield ret
        comb = next(gen)
    yield None
    

filenames_combinations(filenames)
# Out:
# [('BNB', 'BTC'), ('BCH', 'BNB'), ('BCH', 'BTC')]
# ['BNBBTC-2020-02-05', 'BCHBNB-2020-02-05', 'BCHBTC-2020-02-05']

# %%
import numpy as np
from copy import deepcopy

class Arbitrage:
    def __init__(self):
        self.files_reader = Files_reader()
        self.dataframes = self.files_reader.read_files()
        self.current = None
        self.stop = False
        self.arbitrages = []
        
    def initialize(self):
        self.current = [None]*len(self.dataframes)
        for i in range(len(self.dataframes)):
            self.get_next(i)
        
    def get_next(self, index):
        if len(self.dataframes[index]) == 0:
            self.stop = True  # todo - make this more advanced
        self.current[index] = Currency_pair(self.dataframes[index].head(1))
        self.dataframes[index].drop(self.dataframes[index].index[:1], inplace=True)

    def get_oldest(self):
        return np.argmin([float(self.current[0].timestamp), float(self.current[1].timestamp), float(self.current[2].timestamp)])

    def run(self):
        while not self.stop:
            index = self.get_oldest()
            self.get_next(index)
            if self.detection():
                out = []
                for pair in self.current:
                    out.append(pair.to_json())
                out = "{" + "score: " + "1.000" + ", pairs: [" + out[0] + "," + out[1] + "," + out[2] + "]}"
                self.arbitrages.append(out)
                print(out) # uložení do souboru
            
    def detection(self):
        percentage = self.current[1].supply[0] / self.current[0].supply[0] / self.current[2].supply[0]
        if percentage > 1:
            print(percentage)
            return True
        print(percentage)
        return False

# %%
arb = Arbitrage()
arb.initialize()
# arb.run()
# Out:
# ['BCHBNB-2020-02-05', 'BCHBTC-2020-02-05', 'BNBBTC-2020-02-05']
# {'data/BCHBTC-2020-02-05', 'data/BNBBTC-2020-02-05', 'data/BCHBNB-2020-02-05'}
# {'data/BCHBTC-2020-02-05', 'data/BNBBTC-2020-02-05', 'data/BCHBNB-2020-02-05'}
# {'data/BCHBTC-2020-02-05', 'data/BNBBTC-2020-02-05', 'data/BCHBNB-2020-02-05'}
# 0.9976244848099264
# 0.9976244848099264
# 0.9976244848099264
# 0.9976244848099264
# 0.9977448923321716
# 0.9977448923321716
# 0.9977208108277227
# 0.9977208108277227
# 0.9978721870696932
# 0.9978721870696932
# 0.9978721870696932
# 0.9978721870696932
# 0.9978721870696932
# 0.9978721870696932
# 0.9978721870696932
# 0.9978721870696932
# 0.9978721870696932
# 0.9978240167534048
# 0.9977230990273108
# 0.9977230990273108
# 0.9978181383775706
# 0.9979190657167076
# 0.9979190657167076
# 0.9979190657167076
# 0.9979190657167076
# 0.9979190657167076
# 0.9978181383775706
# 0.9978656648428422
# 0.9978656648428422
# 0.997815206425324
# 0.9979102681322193
# 0.9979102681322193
# 0.9979102681322193
# 0.9979102681322193
# 0.9979102681322193
# 0.997708466257976
# 0.997708466257976
# 0.997708466257976
# 0.997708466257976
# 0.9976609427528669
# 0.9976609427528669
# 0.9976609427528669
# 0.9977559942908578
# 0.9977559942908578
# 0.9977559942908578
# 0.9978510639425293
# 0.9978510639425293
# 0.9978510639425293
# 0.9978510639425293
# 0.9978510639425293
# 0.9978510639425293
# 0.9978510639425293
